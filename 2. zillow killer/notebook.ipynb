# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("./datasets/train.csv")
print(f"Train set size: {df.shape}")
print("SO MANY COLUMNS!!: ",df.columns)
# Out:
# Train set size: (1460, 81)
# SO MANY COLUMNS!!:  Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour', 'Utilities', 'LotConfig',
#        'LandSlope', 'Neighborhood', 'Condition1', 'Condition2', 'BldgType',
#        'HouseStyle', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd',
#        'RoofStyle', 'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType',
#        'MasVnrArea', 'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1',
#        'BsmtFinType2', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating',
#        'HeatingQC', 'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF',
#        'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath',
#        'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
#        'TotRmsAbvGrd', 'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType',
# ...

# %% [markdown]
# ### What all I need to do in preprocessing
# - run df = df.drop(
#     df[
#         (df['GrLivArea'] > 4000) &
#         (df['SalePrice'] < 300000)
#     ].index
# ) (these are considered outliers by the official competition guide)
# - Understand all the columns
# - Look for columns that are numeric but need to be treated as categorical, and maybe vice versa
# - drop useless columns + worse one of pairs representing the same thing
# - delete columns with more than 40% null values, except 'PoolQC'
# - find all null columns
# - divide null columns into numerical and categorical
# - immpute the columns accordingly so that no null columns remain
# - find correlations of numerical columns with SalePrice, and do feature engineering on the top 15-20 columns

# %% [markdown]
# ### My understanding of features
# - not imp: [
#
# ]
# - pairs: {
#     'Street' : 'Alley',
#
# }
# - num but cat: 'MSSubClass',

# %%
df['MSSubClass'].dtype
# Out:
# dtype('int64')
